# %%
from kiteconnect import KiteConnect

# %%
api_key = open('api_key.text', 'r').read()
api_secret = open('api_secret.text', 'r').read()

# %%
kite = KiteConnect(api_key=api_key)

# %%
kite.login_url()
# Out:
# 'https://kite.trade/connect/login?api_key=0yvny102khsjlnpr&v=3'

# %%
data = kite.generate_session("BVN6tnETNPIQmiJlbDtgeFQauawUrwoS", api_secret=api_secret)

# %%
data
# Out:
# {'user_type': 'individual',
#  'email': 'kalash.r.tirpude@gmail.com',
#  'user_name': 'Kalash Rajkumar Tirpude',
#  'user_shortname': 'Kalash',
#  'broker': 'ZERODHA',
#  'exchanges': ['BSE', 'MF', 'NSE', 'NFO', 'CDS', 'BFO'],
#  'products': ['CNC', 'NRML', 'MIS', 'BO', 'CO'],
#  'order_types': ['MARKET', 'LIMIT', 'SL', 'SL-M'],
#  'avatar_url': None,
#  'user_id': 'ZB8746',
#  'api_key': '0yvny102khsjlnpr',
#  'access_token': 'LNVEJzM3x2y0wruHxr8QqO6fEaTuVLga',
#  'public_token': '3mCJQ1mLxfbj5Zg2qhFO2sXSwo1l6NLL',
#  'refresh_token': '',
#  'silo': '',
#  'login_time': datetime.datetime(2021, 5, 5, 15, 55, 48),
#  'meta': {'demat_consent': 'physical'}}

# %%
access_token = data["access_token"]
access_token
# Out:
# 'LNVEJzM3x2y0wruHxr8QqO6fEaTuVLga'

# %%
kite.set_access_token(data["access_token"])

# %%
kite.orders()
# Out:
# []

# %%
kite.instruments()
# Out:
# [{'instrument_token': 552830982,
#   'exchange_token': '2159496',
#   'tradingsymbol': 'EURINR21DEC81.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 81.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552830470,
#   'exchange_token': '2159494',
#   'tradingsymbol': 'EURINR21DEC81.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 81.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552826374,
#   'exchange_token': '2159478',
#   'tradingsymbol': 'EURINR21DEC81.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 81.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552825606,
#   'exchange_token': '2159475',
#   'tradingsymbol': 'EURINR21DEC81.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 81.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552837126,
#   'exchange_token': '2159520',
#   'tradingsymbol': 'EURINR21DEC82.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 82.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552835590,
#   'exchange_token': '2159514',
#   'tradingsymbol': 'EURINR21DEC82.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 82.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552828934,
#   'exchange_token': '2159488',
#   'tradingsymbol': 'EURINR21DEC82.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 82.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552828166,
#   'exchange_token': '2159485',
#   'tradingsymbol': 'EURINR21DEC82.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 82.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552817158,
#   'exchange_token': '2159442',
#   'tradingsymbol': 'EURINR21DEC82.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 82.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552816646,
#   'exchange_token': '2159440',
#   'tradingsymbol': 'EURINR21DEC82.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 82.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552756230,
#   'exchange_token': '2159204',
#   'tradingsymbol': 'EURINR21DEC82.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 82.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552754438,
#   'exchange_token': '2159197',
#   'tradingsymbol': 'EURINR21DEC82.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 82.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552652806,
#   'exchange_token': '2158800',
#   'tradingsymbol': 'EURINR21DEC83.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 83.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552651782,
#   'exchange_token': '2158796',
#   'tradingsymbol': 'EURINR21DEC83.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 83.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552456454,
#   'exchange_token': '2158033',
#   'tradingsymbol': 'EURINR21DEC83.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 83.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552455686,
#   'exchange_token': '2158030',
#   'tradingsymbol': 'EURINR21DEC83.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 83.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552459270,
#   'exchange_token': '2158044',
#   'tradingsymbol': 'EURINR21DEC83.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 83.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 552459014,
#   'exchange_token': '2158043',
#   'tradingsymbol': 'EURINR21DEC83.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 83.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551779846,
#   'exchange_token': '2155390',
#   'tradingsymbol': 'EURINR21DEC83.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 83.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551777286,
#   'exchange_token': '2155380',
#   'tradingsymbol': 'EURINR21DEC83.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 83.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551753222,
#   'exchange_token': '2155286',
#   'tradingsymbol': 'EURINR21DEC84.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 84.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551750662,
#   'exchange_token': '2155276',
#   'tradingsymbol': 'EURINR21DEC84.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 84.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551871494,
#   'exchange_token': '2155748',
#   'tradingsymbol': 'EURINR21DEC84.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 84.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551868422,
#   'exchange_token': '2155736',
#   'tradingsymbol': 'EURINR21DEC84.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 84.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551745798,
#   'exchange_token': '2155257',
#   'tradingsymbol': 'EURINR21DEC84.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 84.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551741702,
#   'exchange_token': '2155241',
#   'tradingsymbol': 'EURINR21DEC84.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 84.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551864838,
#   'exchange_token': '2155722',
#   'tradingsymbol': 'EURINR21DEC84.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 84.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551862022,
#   'exchange_token': '2155711',
#   'tradingsymbol': 'EURINR21DEC84.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 84.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551835398,
#   'exchange_token': '2155607',
#   'tradingsymbol': 'EURINR21DEC85.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 85.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551833094,
#   'exchange_token': '2155598',
#   'tradingsymbol': 'EURINR21DEC85.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 85.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551780614,
#   'exchange_token': '2155393',
#   'tradingsymbol': 'EURINR21DEC85.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 85.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551777542,
#   'exchange_token': '2155381',
#   'tradingsymbol': 'EURINR21DEC85.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 85.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551846918,
#   'exchange_token': '2155652',
#   'tradingsymbol': 'EURINR21DEC85.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 85.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551843590,
#   'exchange_token': '2155639',
#   'tradingsymbol': 'EURINR21DEC85.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 85.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551774470,
#   'exchange_token': '2155369',
#   'tradingsymbol': 'EURINR21DEC85.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 85.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551770630,
#   'exchange_token': '2155354',
#   'tradingsymbol': 'EURINR21DEC85.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 85.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551746054,
#   'exchange_token': '2155258',
#   'tradingsymbol': 'EURINR21DEC86.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 86.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551742214,
#   'exchange_token': '2155243',
#   'tradingsymbol': 'EURINR21DEC86.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 86.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551865350,
#   'exchange_token': '2155724',
#   'tradingsymbol': 'EURINR21DEC86.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 86.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551862278,
#   'exchange_token': '2155712',
#   'tradingsymbol': 'EURINR21DEC86.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 86.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551757574,
#   'exchange_token': '2155303',
#   'tradingsymbol': 'EURINR21DEC86.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 86.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551755270,
#   'exchange_token': '2155294',
#   'tradingsymbol': 'EURINR21DEC86.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 86.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551858182,
#   'exchange_token': '2155696',
#   'tradingsymbol': 'EURINR21DEC86.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 86.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551854342,
#   'exchange_token': '2155681',
#   'tradingsymbol': 'EURINR21DEC86.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 86.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551847430,
#   'exchange_token': '2155654',
#   'tradingsymbol': 'EURINR21DEC87.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 87.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551843846,
#   'exchange_token': '2155640',
#   'tradingsymbol': 'EURINR21DEC87.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 87.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551774726,
#   'exchange_token': '2155370',
#   'tradingsymbol': 'EURINR21DEC87.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 87.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551771142,
#   'exchange_token': '2155356',
#   'tradingsymbol': 'EURINR21DEC87.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 87.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551840774,
#   'exchange_token': '2155628',
#   'tradingsymbol': 'EURINR21DEC87.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 87.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551837958,
#   'exchange_token': '2155617',
#   'tradingsymbol': 'EURINR21DEC87.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 87.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551767046,
#   'exchange_token': '2155340',
#   'tradingsymbol': 'EURINR21DEC87.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 87.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551763718,
#   'exchange_token': '2155327',
#   'tradingsymbol': 'EURINR21DEC87.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 87.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551758086,
#   'exchange_token': '2155305',
#   'tradingsymbol': 'EURINR21DEC88.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 88.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551755526,
#   'exchange_token': '2155295',
#   'tradingsymbol': 'EURINR21DEC88.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 88.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551858438,
#   'exchange_token': '2155697',
#   'tradingsymbol': 'EURINR21DEC88.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 88.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551854598,
#   'exchange_token': '2155682',
#   'tradingsymbol': 'EURINR21DEC88.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 88.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551752454,
#   'exchange_token': '2155283',
#   'tradingsymbol': 'EURINR21DEC88.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 88.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551749126,
#   'exchange_token': '2155270',
#   'tradingsymbol': 'EURINR21DEC88.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 88.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551849990,
#   'exchange_token': '2155664',
#   'tradingsymbol': 'EURINR21DEC88.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 88.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551846662,
#   'exchange_token': '2155651',
#   'tradingsymbol': 'EURINR21DEC88.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 88.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551841286,
#   'exchange_token': '2155630',
#   'tradingsymbol': 'EURINR21DEC89.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 89.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551838214,
#   'exchange_token': '2155618',
#   'tradingsymbol': 'EURINR21DEC89.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 89.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551767558,
#   'exchange_token': '2155342',
#   'tradingsymbol': 'EURINR21DEC89.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 89.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551764230,
#   'exchange_token': '2155329',
#   'tradingsymbol': 'EURINR21DEC89.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 89.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551834630,
#   'exchange_token': '2155604',
#   'tradingsymbol': 'EURINR21DEC89.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 89.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551831814,
#   'exchange_token': '2155593',
#   'tradingsymbol': 'EURINR21DEC89.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 89.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551779334,
#   'exchange_token': '2155388',
#   'tradingsymbol': 'EURINR21DEC89.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 89.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551777030,
#   'exchange_token': '2155379',
#   'tradingsymbol': 'EURINR21DEC89.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 89.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551805190,
#   'exchange_token': '2155489',
#   'tradingsymbol': 'EURINR21DEC90.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 90.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551803398,
#   'exchange_token': '2155482',
#   'tradingsymbol': 'EURINR21DEC90.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 90.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551728902,
#   'exchange_token': '2155191',
#   'tradingsymbol': 'EURINR21DEC90.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 90.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551725830,
#   'exchange_token': '2155179',
#   'tradingsymbol': 'EURINR21DEC90.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 90.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551800582,
#   'exchange_token': '2155471',
#   'tradingsymbol': 'EURINR21DEC90.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 90.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551797254,
#   'exchange_token': '2155458',
#   'tradingsymbol': 'EURINR21DEC90.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 90.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551743750,
#   'exchange_token': '2155249',
#   'tradingsymbol': 'EURINR21DEC90.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 90.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551739398,
#   'exchange_token': '2155232',
#   'tradingsymbol': 'EURINR21DEC90.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 90.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551716102,
#   'exchange_token': '2155141',
#   'tradingsymbol': 'EURINR21DEC91.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 91.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551889670,
#   'exchange_token': '2155819',
#   'tradingsymbol': 'EURINR21DEC91.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 91.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551813638,
#   'exchange_token': '2155522',
#   'tradingsymbol': 'EURINR21DEC91.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 91.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551810822,
#   'exchange_token': '2155511',
#   'tradingsymbol': 'EURINR21DEC91.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 91.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551886086,
#   'exchange_token': '2155805',
#   'tradingsymbol': 'EURINR21DEC91.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 91.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551881478,
#   'exchange_token': '2155787',
#   'tradingsymbol': 'EURINR21DEC91.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 91.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551826694,
#   'exchange_token': '2155573',
#   'tradingsymbol': 'EURINR21DEC91.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 91.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551823110,
#   'exchange_token': '2155559',
#   'tradingsymbol': 'EURINR21DEC91.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 91.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551800838,
#   'exchange_token': '2155472',
#   'tradingsymbol': 'EURINR21DEC92.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 92.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551797510,
#   'exchange_token': '2155459',
#   'tradingsymbol': 'EURINR21DEC92.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 92.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551744518,
#   'exchange_token': '2155252',
#   'tradingsymbol': 'EURINR21DEC92.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 92.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551740166,
#   'exchange_token': '2155235',
#   'tradingsymbol': 'EURINR21DEC92.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 92.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551792902,
#   'exchange_token': '2155441',
#   'tradingsymbol': 'EURINR21DEC92.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 92.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551788294,
#   'exchange_token': '2155423',
#   'tradingsymbol': 'EURINR21DEC92.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 92.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551735046,
#   'exchange_token': '2155215',
#   'tradingsymbol': 'EURINR21DEC92.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 92.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551731718,
#   'exchange_token': '2155202',
#   'tradingsymbol': 'EURINR21DEC92.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 92.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551886854,
#   'exchange_token': '2155808',
#   'tradingsymbol': 'EURINR21DEC93.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 93.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551882246,
#   'exchange_token': '2155790',
#   'tradingsymbol': 'EURINR21DEC93.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 93.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551827206,
#   'exchange_token': '2155575',
#   'tradingsymbol': 'EURINR21DEC93.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 93.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551823622,
#   'exchange_token': '2155561',
#   'tradingsymbol': 'EURINR21DEC93.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 93.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551876358,
#   'exchange_token': '2155767',
#   'tradingsymbol': 'EURINR21DEC93.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 93.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551871750,
#   'exchange_token': '2155749',
#   'tradingsymbol': 'EURINR21DEC93.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 93.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551819270,
#   'exchange_token': '2155544',
#   'tradingsymbol': 'EURINR21DEC93.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 93.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551816198,
#   'exchange_token': '2155532',
#   'tradingsymbol': 'EURINR21DEC93.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 93.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551793670,
#   'exchange_token': '2155444',
#   'tradingsymbol': 'EURINR21DEC94.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 94.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551788806,
#   'exchange_token': '2155425',
#   'tradingsymbol': 'EURINR21DEC94.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 94.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551735558,
#   'exchange_token': '2155217',
#   'tradingsymbol': 'EURINR21DEC94.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 94.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 551732230,
#   'exchange_token': '2155204',
#   'tradingsymbol': 'EURINR21DEC94.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 12, 29),
#   'strike': 94.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556106246,
#   'exchange_token': '2172290',
#   'tradingsymbol': 'EURINR21JUL85.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 85.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556103686,
#   'exchange_token': '2172280',
#   'tradingsymbol': 'EURINR21JUL85.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 85.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556045318,
#   'exchange_token': '2172052',
#   'tradingsymbol': 'EURINR21JUL85.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 85.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556042502,
#   'exchange_token': '2172041',
#   'tradingsymbol': 'EURINR21JUL85.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 85.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556115462,
#   'exchange_token': '2172326',
#   'tradingsymbol': 'EURINR21JUL85.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 85.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556113670,
#   'exchange_token': '2172319',
#   'tradingsymbol': 'EURINR21JUL85.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 85.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556038406,
#   'exchange_token': '2172025',
#   'tradingsymbol': 'EURINR21JUL85.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 85.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556035334,
#   'exchange_token': '2172013',
#   'tradingsymbol': 'EURINR21JUL85.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 85.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556014086,
#   'exchange_token': '2171930',
#   'tradingsymbol': 'EURINR21JUL86.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 86.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556011014,
#   'exchange_token': '2171918',
#   'tradingsymbol': 'EURINR21JUL86.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 86.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556129542,
#   'exchange_token': '2172381',
#   'tradingsymbol': 'EURINR21JUL86.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 86.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556126982,
#   'exchange_token': '2172371',
#   'tradingsymbol': 'EURINR21JUL86.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 86.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556023814,
#   'exchange_token': '2171968',
#   'tradingsymbol': 'EURINR21JUL86.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 86.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556022278,
#   'exchange_token': '2171962',
#   'tradingsymbol': 'EURINR21JUL86.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 86.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556124166,
#   'exchange_token': '2172360',
#   'tradingsymbol': 'EURINR21JUL86.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 86.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556121094,
#   'exchange_token': '2172348',
#   'tradingsymbol': 'EURINR21JUL86.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 86.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556099590,
#   'exchange_token': '2172264',
#   'tradingsymbol': 'EURINR21JUL87.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 87.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556096518,
#   'exchange_token': '2172252',
#   'tradingsymbol': 'EURINR21JUL87.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 87.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556038918,
#   'exchange_token': '2172027',
#   'tradingsymbol': 'EURINR21JUL87.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 87.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556035846,
#   'exchange_token': '2172015',
#   'tradingsymbol': 'EURINR21JUL87.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 87.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556110342,
#   'exchange_token': '2172306',
#   'tradingsymbol': 'EURINR21JUL87.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 87.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556107782,
#   'exchange_token': '2172296',
#   'tradingsymbol': 'EURINR21JUL87.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 87.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556032006,
#   'exchange_token': '2172000',
#   'tradingsymbol': 'EURINR21JUL87.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 87.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556028422,
#   'exchange_token': '2171986',
#   'tradingsymbol': 'EURINR21JUL87.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 87.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556024070,
#   'exchange_token': '2171969',
#   'tradingsymbol': 'EURINR21JUL88.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 88.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556022534,
#   'exchange_token': '2171963',
#   'tradingsymbol': 'EURINR21JUL88.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 88.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556124422,
#   'exchange_token': '2172361',
#   'tradingsymbol': 'EURINR21JUL88.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 88.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556121606,
#   'exchange_token': '2172350',
#   'tradingsymbol': 'EURINR21JUL88.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 88.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556018182,
#   'exchange_token': '2171946',
#   'tradingsymbol': 'EURINR21JUL88.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 88.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556015878,
#   'exchange_token': '2171937',
#   'tradingsymbol': 'EURINR21JUL88.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 88.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556118022,
#   'exchange_token': '2172336',
#   'tradingsymbol': 'EURINR21JUL88.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 88.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556115206,
#   'exchange_token': '2172325',
#   'tradingsymbol': 'EURINR21JUL88.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 88.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556110854,
#   'exchange_token': '2172308',
#   'tradingsymbol': 'EURINR21JUL89.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 89.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556108294,
#   'exchange_token': '2172298',
#   'tradingsymbol': 'EURINR21JUL89.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 89.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556032262,
#   'exchange_token': '2172001',
#   'tradingsymbol': 'EURINR21JUL89.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 89.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556028678,
#   'exchange_token': '2171987',
#   'tradingsymbol': 'EURINR21JUL89.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 89.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556104966,
#   'exchange_token': '2172285',
#   'tradingsymbol': 'EURINR21JUL89.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 89.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556102406,
#   'exchange_token': '2172275',
#   'tradingsymbol': 'EURINR21JUL89.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 89.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556044038,
#   'exchange_token': '2172047',
#   'tradingsymbol': 'EURINR21JUL89.7500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 89.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556041478,
#   'exchange_token': '2172037',
#   'tradingsymbol': 'EURINR21JUL89.7500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 89.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556070918,
#   'exchange_token': '2172152',
#   'tradingsymbol': 'EURINR21JUL90.0000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 90.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556067846,
#   'exchange_token': '2172140',
#   'tradingsymbol': 'EURINR21JUL90.0000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 90.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 555998214,
#   'exchange_token': '2171868',
#   'tradingsymbol': 'EURINR21JUL90.2500CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 90.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 555993862,
#   'exchange_token': '2171851',
#   'tradingsymbol': 'EURINR21JUL90.2500PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 90.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556064774,
#   'exchange_token': '2172128',
#   'tradingsymbol': 'EURINR21JUL90.5000CE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 90.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 556061958,
#   'exchange_token': '2172117',
#   'tradingsymbol': 'EURINR21JUL90.5000PE',
#   'name': 'EURINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 7, 28),
#   'strike': 90.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
# ...
#  {'instrument_token': 553778950,
#   'exchange_token': '2163199',
#   'tradingsymbol': 'JPYINR21JUN62.7500CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 62.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 553777158,
#   'exchange_token': '2163192',
#   'tradingsymbol': 'JPYINR21JUN62.7500PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 62.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 547571974,
#   'exchange_token': '2138953',
#   'tradingsymbol': 'JPYINR21JUN63.0000CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 63.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 547570950,
#   'exchange_token': '2138949',
#   'tradingsymbol': 'JPYINR21JUN63.0000PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 63.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 547556102,
#   'exchange_token': '2138891',
#   'tradingsymbol': 'JPYINR21JUN63.2500CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 63.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 547555590,
#   'exchange_token': '2138889',
#   'tradingsymbol': 'JPYINR21JUN63.2500PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 63.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545754886,
#   'exchange_token': '2131855',
#   'tradingsymbol': 'JPYINR21JUN63.5000CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 63.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545753862,
#   'exchange_token': '2131851',
#   'tradingsymbol': 'JPYINR21JUN63.5000PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 63.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545784326,
#   'exchange_token': '2131970',
#   'tradingsymbol': 'JPYINR21JUN63.7500CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 63.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545782278,
#   'exchange_token': '2131962',
#   'tradingsymbol': 'JPYINR21JUN63.7500PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 63.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545763590,
#   'exchange_token': '2131889',
#   'tradingsymbol': 'JPYINR21JUN64.0000CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 64.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545762054,
#   'exchange_token': '2131883',
#   'tradingsymbol': 'JPYINR21JUN64.0000PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 64.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545736454,
#   'exchange_token': '2131783',
#   'tradingsymbol': 'JPYINR21JUN64.2500CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 64.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545736198,
#   'exchange_token': '2131782',
#   'tradingsymbol': 'JPYINR21JUN64.2500PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 64.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545658886,
#   'exchange_token': '2131480',
#   'tradingsymbol': 'JPYINR21JUN64.5000CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 64.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545656326,
#   'exchange_token': '2131470',
#   'tradingsymbol': 'JPYINR21JUN64.5000PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 64.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545593606,
#   'exchange_token': '2131225',
#   'tradingsymbol': 'JPYINR21JUN64.7500CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 64.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545590790,
#   'exchange_token': '2131214',
#   'tradingsymbol': 'JPYINR21JUN64.7500PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 64.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545565702,
#   'exchange_token': '2131116',
#   'tradingsymbol': 'JPYINR21JUN65.0000CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 65.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545562886,
#   'exchange_token': '2131105',
#   'tradingsymbol': 'JPYINR21JUN65.0000PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 65.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545692678,
#   'exchange_token': '2131612',
#   'tradingsymbol': 'JPYINR21JUN65.2500CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 65.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545689862,
#   'exchange_token': '2131601',
#   'tradingsymbol': 'JPYINR21JUN65.2500PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 65.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545558534,
#   'exchange_token': '2131088',
#   'tradingsymbol': 'JPYINR21JUN65.5000CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 65.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545555206,
#   'exchange_token': '2131075',
#   'tradingsymbol': 'JPYINR21JUN65.5000PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 65.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545683718,
#   'exchange_token': '2131577',
#   'tradingsymbol': 'JPYINR21JUN65.7500CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 65.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545680902,
#   'exchange_token': '2131566',
#   'tradingsymbol': 'JPYINR21JUN65.7500PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 65.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545659398,
#   'exchange_token': '2131482',
#   'tradingsymbol': 'JPYINR21JUN66.0000CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 66.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545657094,
#   'exchange_token': '2131473',
#   'tradingsymbol': 'JPYINR21JUN66.0000PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 66.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545594374,
#   'exchange_token': '2131228',
#   'tradingsymbol': 'JPYINR21JUN66.2500CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 66.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545591814,
#   'exchange_token': '2131218',
#   'tradingsymbol': 'JPYINR21JUN66.2500PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 66.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545652742,
#   'exchange_token': '2131456',
#   'tradingsymbol': 'JPYINR21JUN66.5000CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 66.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545648646,
#   'exchange_token': '2131440',
#   'tradingsymbol': 'JPYINR21JUN66.5000PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 66.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545585926,
#   'exchange_token': '2131195',
#   'tradingsymbol': 'JPYINR21JUN66.7500CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 66.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545582086,
#   'exchange_token': '2131180',
#   'tradingsymbol': 'JPYINR21JUN66.7500PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 66.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545559302,
#   'exchange_token': '2131091',
#   'tradingsymbol': 'JPYINR21JUN67.0000CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 67.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545555974,
#   'exchange_token': '2131078',
#   'tradingsymbol': 'JPYINR21JUN67.0000PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 67.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545684230,
#   'exchange_token': '2131579',
#   'tradingsymbol': 'JPYINR21JUN67.2500CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 67.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545681414,
#   'exchange_token': '2131568',
#   'tradingsymbol': 'JPYINR21JUN67.2500PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 67.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545550086,
#   'exchange_token': '2131055',
#   'tradingsymbol': 'JPYINR21JUN67.5000CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 67.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545544966,
#   'exchange_token': '2131035',
#   'tradingsymbol': 'JPYINR21JUN67.5000PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 67.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545676806,
#   'exchange_token': '2131550',
#   'tradingsymbol': 'JPYINR21JUN67.7500CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 67.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545674502,
#   'exchange_token': '2131541',
#   'tradingsymbol': 'JPYINR21JUN67.7500PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 67.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545653254,
#   'exchange_token': '2131458',
#   'tradingsymbol': 'JPYINR21JUN68.0000CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 68.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545649158,
#   'exchange_token': '2131442',
#   'tradingsymbol': 'JPYINR21JUN68.0000PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 68.0,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545586950,
#   'exchange_token': '2131199',
#   'tradingsymbol': 'JPYINR21JUN68.2500CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 68.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545583110,
#   'exchange_token': '2131184',
#   'tradingsymbol': 'JPYINR21JUN68.2500PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 68.25,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545642758,
#   'exchange_token': '2131417',
#   'tradingsymbol': 'JPYINR21JUN68.5000CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 68.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545637382,
#   'exchange_token': '2131396',
#   'tradingsymbol': 'JPYINR21JUN68.5000PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 68.5,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545576710,
#   'exchange_token': '2131159',
#   'tradingsymbol': 'JPYINR21JUN68.7500CE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 68.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'CE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  {'instrument_token': 545574662,
#   'exchange_token': '2131151',
#   'tradingsymbol': 'JPYINR21JUN68.7500PE',
#   'name': 'JPYINR',
#   'last_price': 0.0,
#   'expiry': datetime.date(2021, 6, 28),
#   'strike': 68.75,
#   'tick_size': 0.0025,
#   'lot_size': 1,
#   'instrument_type': 'PE',
#   'segment': 'BCD-OPT',
#   'exchange': 'BCD'},
#  ...]
